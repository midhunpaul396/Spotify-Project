# %% [markdown]
# # Import Data to Database

# %%
# !pip install pymongo
import pandas as panda
spotifyDataset=panda.read_csv('https://raw.githubusercontent.com/midhunpaul396/Group-Project/main/SpotifyFinalTwo.csv')

# %%
spotifyDataset
# Out:
#       Index              Title                    Artist                Genre  \
# 0         1            Sunrise               Norah Jones      adult standards
# 1         2         BlackNight               Deep Purple           album rock
# 2         3      ClintEastwood                  Gorillaz  alternative hip hop
# 3         4       ThePretender              Foo Fighters    alternative metal
# 4         5  WaitinOnASunnyDay         Bruce Springsteen         classic rock
# ...     ...                ...                       ...                  ...
# 1989   1990    HeartbreakHotel             Elvis Presley      adult standards
# 1990   1991           HoundDog             Elvis Presley      adult standards
# 1991   1992       JohnnyBGoode               Chuck Berry           blues rock
# 1992   1993           TakeFive  The Dave Brubeck Quartet                bebop
# 1993   1994      BlueberryHill               Fats Domino      adult standards
#
# ...

# %%
import pandas as panda
from pymongo import MongoClient
data = spotifyDataset
client = MongoClient("mongodb+srv://TeamRNM:TeamRNM@cluster0.ntlrzu1.mongodb.net/?retryWrites=true&w=majority")

# %%
db = client['TeamRNM']
collection = db['spotify']
data_dict = data.to_dict("records")
collection.insert_many(data_dict)

# %%
collection.count_documents({})
# Out:
# 1994

# %% [markdown]
# # Fetching data from Database

# %%
all_records = collection.find()
print(all_records)
list_cursor = list(all_records)
print(list_cursor)
# Out:
# ...
# [{'_id': ObjectId('643f809cc179ca192259d4bc'), 'Index': 1, 'Title': 'Sunrise', 'Artist': 'Norah Jones', 'Genre': 'adult standards', 'Year': 2004, 'Beats Per Minute (BPM)': 157, 'Energy': 30, 'Danceability': 53, 'Loudness (dB)': -14, 'Liveness': 11, 'Valence': 68, 'Length (Duration)': '201', 'Acousticness': 94, 'Speechiness': 3, 'Popularity': 71}, {'_id': ObjectId('643f809cc179ca192259d4bd'), 'Index': 2, 'Title': 'BlackNight', 'Artist': 'Deep Purple', 'Genre': 'album rock', 'Year': 2000, 'Beats Per Minute (BPM)': 135, 'Energy': 79, 'Danceability': 50, 'Loudness (dB)': -11, 'Liveness': 17, 'Valence': 81, 'Length (Duration)': '207', 'Acousticness': 17, 'Speechiness': 7, 'Popularity': 39}, {'_id': ObjectId('643f809cc179ca192259d4be'), 'Index': 3, 'Title': 'ClintEastwood', 'Artist': 'Gorillaz', 'Genre': 'alternative hip hop', 'Year': 2001, 'Beats Per Minute (BPM)': 168, 'Energy': 69, 'Danceability': 66, 'Loudness (dB)': -9, 'Liveness': 7, 'Valence': 52, 'Length (Duration)': '341', 'Acoust
# ...

# %% [markdown]
# # Creating Pandas DataFrame from list_cursor object

# %%
spotifyDataset = panda.DataFrame(list_cursor)
spotifyDataset

# %% [markdown]
# # Chart 1 Top 10 tracks after 2000 with highest popularity

# %%
dataFrameNew = spotifyDataset[spotifyDataset['Year'] >= 2000]
dataFrameNew = dataFrameNew.sort_values(by='Popularity', ascending=False).head(10)
dataFrameNew
# Out:
#                           _id  Index        Title               Artist  \
# 793  643f809cc179ca192259d7d5    794  DanceMonkey          Tones and I
# 787  643f809cc179ca192259d7cf    788     Memories             Maroon 5
# 786  643f809cc179ca192259d7ce    787       badguy        Billie Eilish
# 726  643f809cc179ca192259d792    727      Shallow            Lady Gaga
# 688  643f809cc179ca192259d76c    689     Believer      Imagine Dragons
# 745  643f809cc179ca192259d7a5    746    HighHopes  Panic! At The Disco
# 687  643f809cc179ca192259d76b    688   ShapeofYou           Ed Sheeran
# 683  643f809cc179ca192259d767    684      Perfect           Ed Sheeran
# 529  643f809cc179ca192259d6cd    530      AllofMe          John Legend
# 706  643f809cc179ca192259d77e    707      Thunder      Imagine Dragons
#
#               Genre  Year  Beats Per Minute (BPM)  Energy  Danceability  \
# 793  australian pop  2019                      98      59            82
# ...

# %% [markdown]
# # Chart 2 Top 10 Tracks of Eminem

# %%
dataFrameEminem = spotifyDataset[spotifyDataset['Artist'] == 'Eminem']
dataFrameEminem = dataFrameEminem.sort_values(by='Popularity', ascending=False).head(10)
dataFrameEminem
# Out:
#                            _id  Index                           Title  Artist  \
# 9     643f809cc179ca192259d4c5     10                       WithoutMe  Eminem
# 192   643f809cc179ca192259d57c    193                TheRealSlimShady  Eminem
# 114   643f809cc179ca192259d52e    115  LoseYourselfFromMileSoundtrack  Eminem
# 219   643f809cc179ca192259d597    220                            Stan  Eminem
# 546   643f809cc179ca192259d6de    547                      TheMonster  Eminem
# 1824  643f809cc179ca192259dbdc   1825                        MyNameIs  Eminem
# 27    643f809cc179ca192259d4d7     28              CleaninOutMyCloset  Eminem
#
#                 Genre  Year  Beats Per Minute (BPM)  Energy  Danceability  \
# 9     detroit hip hop  2002                     112      67            91
# 192   detroit hip hop  2000                     105      66            95
# 114   detroit hip hop  2005                     171      74            69
# ...

# %% [markdown]
# # Chart 3 Top 10 Genre with highest popularity average

# %%
# group the DataFrame by 'Genre' column and calculate mean of 'Popularity' for each group
genre_popularity = spotifyDataset.groupby('Genre')['Popularity'].mean()

# sort the resulting Series in descending order and select top 10 rows
top10_popularity_genres = genre_popularity.sort_values(ascending=False).head(10)

top10_popularity_genres_df = top10_popularity_genres.to_frame()

top10_popularity_genres_df
# Out:
#                   Popularity
# Genre
# celtic punk        83.000000
# indie pop          83.000000
# australian psych   80.500000
# ccm                80.000000
# electro house      80.000000
# danish pop         80.000000
# atl hip hop        79.000000
# pop punk           79.000000
# electropop         78.333333
# la pop             78.000000

# %% [markdown]
# # Chart 4 Artists with highest average song releases per year

# %%
# Filter the dataset to include only the top 10 artists based on the number of songs released
top10_artists = spotifyDataset.groupby('Artist')['Title'].count().sort_values(ascending=False).head(10).index.tolist()
dataFrameTwo = spotifyDataset[spotifyDataset['Artist'].isin(top10_artists)]

# Group the filtered DataFrame by 'Artist' and 'Year' columns and count the number of songs for each group
grouped = dataFrameTwo.groupby(['Artist', 'Year'])['Title'].count().reset_index()

# Calculate the average number of songs released by each artist in a year
avg_songs_per_artist = grouped.groupby('Artist')['Title'].mean().sort_values(ascending=False).head(10)

# Convert the resulting Series to a DataFrame and reset the index
avg_songs_per_artist_df = avg_songs_per_artist.to_frame().reset_index()

# Rename the columns to reflect the data
avg_songs_per_artist_df.columns = ['Artist', 'Average number of songs released']

# Display the resulting DataFrame
avg_songs_per_artist_df
# Out:
#                Artist  Average number of songs released
# 0            Coldplay                          3.375000
# 1       Fleetwood Mac                          3.000000
# 2         The Beatles                          3.000000
# 3               Queen                          2.846154
# 4                ABBA                          2.750000
# 5                  U2                          2.363636
# 6     Michael Jackson                          2.300000
# 7   Bruce Springsteen                          2.090909
# 8  The Rolling Stones                          1.846154
# 9         David Bowie                          1.400000

# %% [markdown]
# # Using Flask to Generate Visualizations

# %%
from flask import Flask, render_template
import pandas as pd
import json

app = Flask(__name__)

@app.route('/')
def index():
    return render_template('index.html')

@app.route('/chart1')
def chart1():
    data = [['Title', 'Popularity']]
    for _, row in dataFrameNew.iterrows():
        data.append([row['Title'], row['Popularity']])
    chart_data = json.dumps(data)
    chart_title = 'Top 10 tracks after 2000 with the highest popularity'
    h_title = 'Song'
    v_title = 'Popularity'
    return render_template('visualizations.html', chart_data=chart_data, chart_title=chart_title, h_title=h_title, v_title=v_title)

@app.route('/chart2')
def chart2():
    data = [['Genre', 'Popularity']]
    for genre, row in top10_popularity_genres_df.iterrows():
        data.append([genre, row['Popularity']])
    chart_data = json.dumps(data)
    chart_title = 'Top 10 Genre with the highest popularity average'
    h_title = 'Genre'
    v_title = 'Popularity'
    return render_template('visualizations.html', chart_data=chart_data, chart_title=chart_title, h_title=h_title, v_title=v_title)

@app.route('/chart3')
def chart3():
    data = [['Title', 'Popularity']]
    for _, row in dataFrameEminem.iterrows():
        data.append([row['Title'], row['Popularity']])
    chart_data = json.dumps(data)
    chart_title = 'Top 10 tracks of Eminem'
    h_title = 'Song'
    v_title = 'Popularity'
    return render_template('visualizations.html', chart_data=chart_data, chart_title=chart_title, h_title=h_title, v_title=v_title)

@app.route('/chart4')
def chart4():
    data = [['Artist', 'Average number of songs released']]
    for _, row in avg_songs_per_artist_df.iterrows():
        data.append([row['Artist'], row['Average number of songs released']])
    chart_data = json.dumps(data)
    chart_title = 'Average number of songs released'
    h_title = 'Artist'
    v_title = 'Average number of songs released'
    return render_template('visualizations.html', chart_data=chart_data, chart_title=chart_title, h_title=h_title, v_title=v_title)

if __name__ == '__main__':
    app.run()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [19/Apr/2023 22:12:41] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [19/Apr/2023 22:12:42] "GET /chart1 HTTP/1.1" 200 -
# 127.0.0.1 - - [19/Apr/2023 22:12:52] "GET /chart3 HTTP/1.1" 200 -
# 127.0.0.1 - - [19/Apr/2023 22:13:12] "GET /chart4 HTTP/1.1" 200 -
# 127.0.0.1 - - [19/Apr/2023 22:13:24] "GET /chart1 HTTP/1.1" 200 -
# 127.0.0.1 - - [20/Apr/2023 17:45:59] "GET /chart1 HTTP/1.1" 200 -

# %% [markdown]
# # Running the code every 24 hours

# %%
while True:
    import time
    import sqlite3
    from flask import Flask, render_template
    import pandas as pd
    import json
    import pandas as panda
    from pymongo import MongoClient
    
    client = MongoClient("mongodb+srv://TeamRNM:TeamRNM@cluster0.ntlrzu1.mongodb.net/?retryWrites=true&w=majority") 
    db = client['TeamRNM']
    collection = db['spotify']
    all_records = collection.find()
    list_cursor = list(all_records)
    spotifyDataset = panda.DataFrame(list_cursor)
    
    app = Flask(__name__)

    @app.route('/')
    def index():
        return render_template('index.html')

    @app.route('/chart1')
    def chart1():
        data = [['Title', 'Popularity']]
        for _, row in dataFrameNew.iterrows():
            data.append([row['Title'], row['Popularity']])
        chart_data = json.dumps(data)
        chart_title = 'Top 10 tracks after 2000 with the highest popularity'
        h_title = 'Song'
        v_title = 'Popularity'
        return render_template('visualizations.html', chart_data=chart_data, chart_title=chart_title, h_title=h_title, v_title=v_title)

    @app.route('/chart2')
    def chart2():
        data = [['Genre', 'Popularity']]
        for genre, row in top10_popularity_genres_df.iterrows():
            data.append([genre, row['Popularity']])
        chart_data = json.dumps(data)
        chart_title = 'Top 10 Genre with the highest popularity average'
        h_title = 'Genre'
        v_title = 'Popularity'
        return render_template('visualizations.html', chart_data=chart_data, chart_title=chart_title, h_title=h_title, v_title=v_title)

    @app.route('/chart3')
    def chart3():
        data = [['Title', 'Popularity']]
        for _, row in dataFrameEminem.iterrows():
            data.append([row['Title'], row['Popularity']])
        chart_data = json.dumps(data)
        chart_title = 'Top 10 tracks of Eminem'
        h_title = 'Song'
        v_title = 'Popularity'
        return render_template('visualizations.html', chart_data=chart_data, chart_title=chart_title, h_title=h_title, v_title=v_title)

    @app.route('/chart4')
    def chart4():
        data = [['Artist', 'Average number of songs released']]
        for _, row in avg_songs_per_artist_df.iterrows():
            data.append([row['Artist'], row['Average number of songs released']])
        chart_data = json.dumps(data)
        chart_title = 'Average number of songs released'
        h_title = 'Artist'
        v_title = 'Average number of songs released'
        return render_template('visualizations.html', chart_data=chart_data, chart_title=chart_title, h_title=h_title, v_title=v_title)

    if __name__ == '__main__':
        app.run()

    time.sleep(86400)
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
